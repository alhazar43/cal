# %%
import pickle
import os
import numpy as np  
import pandas as pd
import matplotlib.pyplot as plt

with open('debug.pkl', 'rb') as f:
    data = pickle.load(f)

# %%
data
# Out:
# {'est_theta_history': array([[ 0.01939469,  2.20509636],
#         [ 0.85397555,  0.980603  ],
#         [ 0.67557765,  0.79664263],
#         [ 0.5256897 ,  0.71585279],
#         [ 0.57013072,  0.79521684],
#         [ 0.49459418,  0.68395984],
#         [ 0.21474476,  0.64159978],
#         [ 0.10912196,  0.59383796],
#         [-0.25062579,  0.66093434],
#         [-0.17040945,  0.71264997],
#         [-0.3562513 ,  0.71931165],
#         [-0.59130073,  0.76335762],
#         [-0.60149202,  0.71298446],
#         [-0.44185988,  0.64992573],
#         [-0.41528307,  0.59776097],
#         [-0.43383866,  0.60571155],
#         [-0.38558873,  0.60553845],
#         [-0.3101391 ,  0.61791658],
#         [-0.29483381,  0.56824495],
#         [-0.26474529,  0.48146445],
#         [-0.26643211,  0.49421808]]),
#  'info_gain_list': [1.1291204997031636,
#   1.411217594264948,
#   1.6075015004363211,
#   1.288664693641005,
#   1.4408626516680403,
#   1.4510774450016422,
# ...

# %%
with open(os.path.join('results', 'atr_0.pkl'), 'rb') as f:
    atr_0  = pickle.load(f)

# %%
atr_0
# Out:
# {'est_theta_history': array([[ 1.22959873, -1.85014405],
#         [-0.22661817, -0.22010054],
#         [-0.30250846, -0.29461044],
#         [-0.52416649, -0.55994766],
#         [-0.34992215, -0.09057232],
#         [-0.32688418, -0.04911453],
#         [-0.26774956,  0.08509912],
#         [-0.37816066,  0.00769998],
#         [-0.42270939, -0.09610655],
#         [-0.32134993, -0.09754887],
#         [-0.30578492, -0.18909992],
#         [-0.43789915, -0.11359991],
#         [-0.38198788, -0.01816557],
#         [-0.35161908, -0.12600896],
#         [-0.39235054,  0.06733857],
#         [-0.36823273, -0.0388581 ],
#         [-0.39760623, -0.03680876],
#         [-0.38097878, -0.05927953],
#         [-0.37893099, -0.07471751],
#         [-0.45236624,  0.07002964],
#         [-0.40405785,  0.09013733]]),
#  'info_gain_list': [1.2774195808212823,
#   1.250603566487573,
#   1.0146768705935834,
#   0.7359179155893684,
#   1.1359399995796466,
#   1.1206155434418548,
# ...
